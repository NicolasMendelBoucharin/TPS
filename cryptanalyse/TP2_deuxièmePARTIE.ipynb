# %% [markdown]
# - On doit verifier la propriété sur 3 tours :
#   - chiffre une collection de 16 messages
# - Attaquer sur 4 tours
#   - retouver la dernière sous-clé mot de de 4 bits par mot de 4 bits (là où il y a la propriété 0)
#   - deviner la partie manquante
